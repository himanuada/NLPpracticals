# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tarfile

# Path to the tar.gz file
file_path = '/content/drive/MyDrive/eng_news-typical_2016_10K.tar.gz'

# Extract the contents of the tar.gz file
with tarfile.open(file_path, 'r:gz') as tar:
    tar.extractall('/content/drive/MyDrive/eng_news-typical_2016_10K')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-95de3bea17f0> in <cell line: 7>()
#       5
#       6 # Extract the contents of the tar.gz file
# ----> 7 with tarfile.open(file_path, 'r:gz') as tar:
#       8     tar.extractall('/content/drive/MyDrive/eng_news-typical_2016_10K')
#
# /usr/lib/python3.10/tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1815             else:
#    1816                 raise CompressionError("unknown compression type %r" % comptype)
# -> 1817             return func(name, filemode, fileobj, **kwargs)
#    1818
#    1819         elif "|" in mode:
#
# /usr/lib/python3.10/tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1861
#    1862         try:
# -> 1863             fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1864         except OSError as e:
# ...

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = '/content/drive/MyDrive/eng_news-typical_2016_10K'
filelist = PlaintextCorpusReader(corpus_root, '.*')
print ('\n File list: \n')
print (filelist.fileids())

print (filelist.root)

'''display other information about each text, by looping over all the values of fileid
corresponding to the filelist file identifiers listed earlier and then computing statistics
for each text.'''

print ('\n\nStatistics for each text:\n')
print
('AvgWordLen\tAvgSentenceLen\tno.ofTimesEachWordAppearsOnAvg\tFileName')
for fileid in filelist.fileids():
    num_chars = len(filelist.raw(fileid))
    num_words = len(filelist.words(fileid))
    num_sents = len(filelist.sents(fileid))
    num_vocab = len(set([w.lower() for w in filelist.words(fileid)]))
    print (int(num_chars/num_words),'\t\t\t', int(num_words/num_sents),'\t\t\t',int(num_words/num_vocab),'\t\t', fileid)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-0015c5d708cf> in <cell line: 3>()
#       1 from nltk.corpus import PlaintextCorpusReader
#       2 corpus_root = '/content/drive/MyDrive/eng_news-typical_2016_10K'
# ----> 3 filelist = PlaintextCorpusReader(corpus_root, '.*')
#       4 print ('\n File list: \n')
#       5 print (filelist.fileids())
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/reader/plaintext.py in __init__(self, root, fileids, word_tokenizer, sent_tokenizer, para_block_reader, encoding)
#      60             corpus into paragraph blocks.
#      61         """
# ---> 62         CorpusReader.__init__(self, root, fileids, encoding)
#      63         self._word_tokenizer = word_tokenizer
#      64         self._sent_tokenizer = sent_tokenizer
#
# ...
