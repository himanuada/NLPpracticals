# %%
from __future__ import with_statement
import re

# %%
words = []
testword = []
ans = []

# %%
print("MENU")
print("-----------")
print(" 1 . Hash tag segmentation ")
print(" 2 . URL segmentation ")
print("enter the input choice for performing word segmentation")
choice = int(input())
# Out:
# MENU
# -----------
#  1 . Hash tag segmentation
#  2 . URL segmentation
# enter the input choice for performing word segmentation
# 1

# %%
import os
cwd = os.getcwd()
files = os.listdir(cwd)
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/content': ['.config', 'sample_data']

# %%
if choice == 1:
  text = "what is my name?"
  print("input with HashTag",text)
  pattern=re.compile("[^\w']")
  a = pattern.sub('', text)
elif choice == 2:
  text = "wwwhatismyname.com"
  print("input with URL",text)
  a=re.split('\s|(?<!\d)[,.](?!\d)', text)
  splitwords = ["www","com","in"]
  a ="".join([each for each in a if each not in splitwords])
else:
  print("wrong choice...try again")
  print(a)
for each in a:
  testword.append(each)
test_length = len(testword)
# Out:
# input with HashTag what is my name?

# %%
with open('/content/drive/MyDrive/dataset/word.txt','r') as f:
  lines = f.readlines()
  words =[(e.strip()) for e in lines]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-46afec47fffe> in <cell line: 1>()
# ----> 1 with open('/content/drive/MyDrive/dataset/word.txt','r') as f:
#       2   lines = f.readlines()
#       3   words =[(e.strip()) for e in lines]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/dataset/word.txt'
