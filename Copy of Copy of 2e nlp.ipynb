# %%
import nltk
from collections import defaultdict
nltk.download('punkt')
text = nltk.word_tokenize("Nick likes to play football. Nick does not like to playcricket.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nltk.download('averaged_perceptron_tagger')
tagged = nltk.pos_tag(text)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
print(tagged)
# Out:
# [('Nick', 'NNP'), ('likes', 'VBZ'), ('to', 'TO'), ('play', 'VB'), ('football', 'NN'), ('.', '.'), ('Nick', 'NNP'), ('does', 'VBZ'), ('not', 'RB'), ('like', 'VB'), ('to', 'TO'), ('playcricket', 'VB'), ('.', '.')]

# %%
addNounWords = []
count=0

# %%
for words in tagged:
  val = tagged[count][1]
  if (val=="NN" or val == "NNS" or val == "NNPS" or val == "NNP"):
    addNounWords.append(tagged[count][0])
    count+=1

# %%
print (addNounWords)
# Out:
# []

# %%
temp = defaultdict(int)

# %%
for sub in addNounWords:
  for wrd in sub.split():
    temp[wrd]+=1

# %%
res = max(temp, key=temp.get)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c872740db185> in <cell line: 1>()
# ----> 1 res = max(temp, key=temp.get)
#
# NameError: name 'temp' is not defined

# %%
print("Word with maximum frequency : " + str(res))
# Out:
# Word with maximum frequency : Nick
